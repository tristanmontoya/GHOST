# %%
# GHOST - Euler Test (2D)

import sys  
import numpy as np
import modepy as mp
sys.path.insert(0, '../src')
from Mesh import Mesh2D
from Discretization import SpatialDiscretization
from Solver import Solver

# discretization degree
p = 2

# geometry mapping degree (isoparametric)
p_geo = p

# read in mesh in GMSH format
mesh = Mesh2D("test", "../mesh/square_mesh_L20_x_21y_21.msh")

# set up periodic boundary conditions
left = np.array([1.0,0.0,0.0]) 
right = np.array([1.0,0.0,20.0])
bottom = np.array([0.0,1.0,0.0])
top = np.array([0.0,1.0,20.0])
mesh.add_bc_on_hyperplanes([left,right,bottom,top],[1,2,3,4])
mesh.make_periodic((1,2),[1]) # left-right periodic (bcs parallel to axis 1)
mesh.make_periodic((3,4),[0]) # top-bottom periodic (axis 0)

#curvilinear transformation used in Del Rey Fernandez et al. (2017)
mesh.map_mesh(f_map=Mesh2D.grid_transformation(warp_factor=0.2, L=20.0), p_geo=p_geo)

# volume and facet quadrature degrees
tau = 2*p
mu = 2*p+1

# solver parameters
params = {"project_title": "euler_p2cpt1",
         "problem": "compressible_euler",
         "specific_heat_ratio": 1.4,
         "numerical_flux": "roe",
         "initial_condition": "isentropic_vortex",
         "initial_vortex_centre": np.array([5.0,5.0]),
         "background_temperature": 1.0,
         "background_velocity": np.array([1.0,1.0]),
         "integration_type": "quadrature",
         "solution_degree": p,
         "volume_quadrature_degree": tau,
         "facet_quadrature_degree": mu,
         "solution_representation": "modal",
         "form": "weak",
         "correction": "c_+",
         "time_integrator": "rk44",
         "final_time": 10.0,
         "time_step_scale": 0.005}

# set up solver
solver = Solver(params,mesh)
weak = Solver(params,mesh)
params_strong = params.copy()
params_strong["form"] = "strong"
strong = Solver(params_strong,mesh)

# %%
strong.run(write_interval=0.005)
strong.post_process(error_quadrature_degree=4*p)
# Out:
# dt =  0.00025
# writing every  20  time steps, total  80000
# writing time step  20 : t =  0.005000000000000003
# writing time step  40 : t =  0.010000000000000007
# writing time step  60 : t =  0.015000000000000012
# writing time step  80 : t =  0.020000000000000014
# writing time step  100 : t =  0.02500000000000002
# writing time step  120 : t =  0.030000000000000023
# writing time step  140 : t =  0.035000000000000024
# writing time step  160 : t =  0.04000000000000003
# writing time step  180 : t =  0.04500000000000003
# writing time step  200 : t =  0.05000000000000004
# writing time step  220 : t =  0.05500000000000004
# writing time step  240 : t =  0.060000000000000046
# writing time step  260 : t =  0.06500000000000004
# writing time step  280 : t =  0.07000000000000005
# writing time step  300 : t =  0.07500000000000005
# writing time step  320 : t =  0.08000000000000006
# writing time step  340 : t =  0.08500000000000006
# writing time step  360 : t =  0.09000000000000007
# writing time step  380 : t =  0.09500000000000007
# writing time step  400 : t =  0.10000000000000007
# writing time step  420 : t =  0.10500000000000008
# writing time step  440 : t =  0.11000000000000008
# writing time step  460 : t =  0.11500000000000009
# writing time step  480 : t =  0.12000000000000009
# writing time step  500 : t =  0.12500000000000008
# writing time step  520 : t =  0.1300000000000001
# writing time step  540 : t =  0.1350000000000001
# writing time step  560 : t =  0.1400000000000001
# writing time step  580 : t =  0.1450000000000001
# writing time step  600 : t =  0.1500000000000001
# writing time step  620 : t =  0.1550000000000001
# writing time step  640 : t =  0.16000000000000011
# writing time step  660 : t =  0.16500000000000012
# writing time step  680 : t =  0.17000000000000012
# writing time step  700 : t =  0.17500000000000013
# writing time step  720 : t =  0.18000000000000013
# writing time step  740 : t =  0.18500000000000014
# writing time step  760 : t =  0.19000000000000014
# writing time step  780 : t =  0.19500000000000015
# writing time step  800 : t =  0.20000000000000015
# writing time step  820 : t =  0.20500000000000015
# writing time step  840 : t =  0.21000000000000016
# writing time step  860 : t =  0.21500000000000016
# writing time step  880 : t =  0.22000000000000017
# writing time step  900 : t =  0.22500000000000017
# writing time step  920 : t =  0.23000000000000018
# writing time step  940 : t =  0.23500000000000018
# writing time step  960 : t =  0.24000000000000019
# writing time step  980 : t =  0.2450000000000002
# writing time step  1000 : t =  0.25000000000000017
# writing time step  1020 : t =  0.2549999999999996
# writing time step  1040 : t =  0.25999999999999907
# writing time step  1060 : t =  0.2649999999999985
# writing time step  1080 : t =  0.26999999999999796
# writing time step  1100 : t =  0.2749999999999974
# writing time step  1120 : t =  0.27999999999999686
# writing time step  1140 : t =  0.2849999999999963
# writing time step  1160 : t =  0.28999999999999576
# writing time step  1180 : t =  0.2949999999999952
# writing time step  1200 : t =  0.29999999999999466
# writing time step  1220 : t =  0.3049999999999941
# writing time step  1240 : t =  0.30999999999999356
# writing time step  1260 : t =  0.314999999999993
# writing time step  1280 : t =  0.31999999999999246
# writing time step  1300 : t =  0.3249999999999919
# writing time step  1320 : t =  0.32999999999999136
# writing time step  1340 : t =  0.3349999999999908
# writing time step  1360 : t =  0.33999999999999025
# writing time step  1380 : t =  0.3449999999999897
# writing time step  1400 : t =  0.34999999999998915
# writing time step  1420 : t =  0.3549999999999886
# writing time step  1440 : t =  0.35999999999998805
# writing time step  1460 : t =  0.3649999999999875
# writing time step  1480 : t =  0.36999999999998695
# writing time step  1500 : t =  0.3749999999999864
# writing time step  1520 : t =  0.37999999999998585
# writing time step  1540 : t =  0.3849999999999853
# writing time step  1560 : t =  0.38999999999998475
# writing time step  1580 : t =  0.3949999999999842
# writing time step  1600 : t =  0.39999999999998365
# writing time step  1620 : t =  0.4049999999999831
# writing time step  1640 : t =  0.40999999999998255
# writing time step  1660 : t =  0.414999999999982
# writing time step  1680 : t =  0.41999999999998144
# writing time step  1700 : t =  0.4249999999999809
# writing time step  1720 : t =  0.42999999999998034
# writing time step  1740 : t =  0.4349999999999798
# writing time step  1760 : t =  0.43999999999997924
# writing time step  1780 : t =  0.4449999999999787
# writing time step  1800 : t =  0.44999999999997814
# writing time step  1820 : t =  0.4549999999999776
# writing time step  1840 : t =  0.45999999999997704
# writing time step  1860 : t =  0.4649999999999765
# writing time step  1880 : t =  0.46999999999997594
# writing time step  1900 : t =  0.4749999999999754
# writing time step  1920 : t =  0.47999999999997484
# writing time step  1940 : t =  0.4849999999999743
# writing time step  1960 : t =  0.48999999999997373
# writing time step  1980 : t =  0.4949999999999732
# writing time step  2000 : t =  0.49999999999997263
# writing time step  2020 : t =  0.5049999999999721
# writing time step  2040 : t =  0.5099999999999716
# writing time step  2060 : t =  0.514999999999971
# writing time step  2080 : t =  0.5199999999999705
# writing time step  2100 : t =  0.5249999999999699
# writing time step  2120 : t =  0.5299999999999694
# writing time step  2140 : t =  0.5349999999999688
# writing time step  2160 : t =  0.5399999999999683
# writing time step  2180 : t =  0.5449999999999677
# writing time step  2200 : t =  0.5499999999999672
# writing time step  2220 : t =  0.5549999999999666
# writing time step  2240 : t =  0.5599999999999661
# writing time step  2260 : t =  0.5649999999999655
# writing time step  2280 : t =  0.569999999999965
# writing time step  2300 : t =  0.5749999999999644
# writing time step  2320 : t =  0.5799999999999639
# writing time step  2340 : t =  0.5849999999999633
# writing time step  2360 : t =  0.5899999999999628
# writing time step  2380 : t =  0.5949999999999622
# writing time step  2400 : t =  0.5999999999999617
# writing time step  2420 : t =  0.6049999999999611
# writing time step  2440 : t =  0.6099999999999606
# writing time step  2460 : t =  0.61499999999996
# writing time step  2480 : t =  0.6199999999999595
# writing time step  2500 : t =  0.6249999999999589
# writing time step  2520 : t =  0.6299999999999584
# writing time step  2540 : t =  0.6349999999999578
# writing time step  2560 : t =  0.6399999999999573
# writing time step  2580 : t =  0.6449999999999567
# writing time step  2600 : t =  0.6499999999999562
# writing time step  2620 : t =  0.6549999999999556
# writing time step  2640 : t =  0.6599999999999551
# writing time step  2660 : t =  0.6649999999999545
# writing time step  2680 : t =  0.669999999999954
# writing time step  2700 : t =  0.6749999999999534
# writing time step  2720 : t =  0.6799999999999529
# writing time step  2740 : t =  0.6849999999999523
# writing time step  2760 : t =  0.6899999999999518
# writing time step  2780 : t =  0.6949999999999512
# writing time step  2800 : t =  0.6999999999999507
# writing time step  2820 : t =  0.7049999999999501
# writing time step  2840 : t =  0.7099999999999496
# writing time step  2860 : t =  0.714999999999949
# writing time step  2880 : t =  0.7199999999999485
# writing time step  2900 : t =  0.7249999999999479
# writing time step  2920 : t =  0.7299999999999474
# writing time step  2940 : t =  0.7349999999999468
# writing time step  2960 : t =  0.7399999999999463
# writing time step  2980 : t =  0.7449999999999457
# writing time step  3000 : t =  0.7499999999999452
# writing time step  3020 : t =  0.7549999999999446
# writing time step  3040 : t =  0.759999999999944
# writing time step  3060 : t =  0.7649999999999435
# writing time step  3080 : t =  0.769999999999943
# writing time step  3100 : t =  0.7749999999999424
# writing time step  3120 : t =  0.7799999999999419
# writing time step  3140 : t =  0.7849999999999413
# writing time step  3160 : t =  0.7899999999999407
# writing time step  3180 : t =  0.7949999999999402
# writing time step  3200 : t =  0.7999999999999396
# writing time step  3220 : t =  0.8049999999999391
# writing time step  3240 : t =  0.8099999999999385
# writing time step  3260 : t =  0.814999999999938
# writing time step  3280 : t =  0.8199999999999374
# writing time step  3300 : t =  0.8249999999999369
# writing time step  3320 : t =  0.8299999999999363
# writing time step  3340 : t =  0.8349999999999358
# writing time step  3360 : t =  0.8399999999999352
# writing time step  3380 : t =  0.8449999999999347
# writing time step  3400 : t =  0.8499999999999341
# writing time step  3420 : t =  0.8549999999999336
# writing time step  3440 : t =  0.859999999999933
# writing time step  3460 : t =  0.8649999999999325
# writing time step  3480 : t =  0.8699999999999319
# writing time step  3500 : t =  0.8749999999999314
# writing time step  3520 : t =  0.8799999999999308
# writing time step  3540 : t =  0.8849999999999303
# writing time step  3560 : t =  0.8899999999999297
# writing time step  3580 : t =  0.8949999999999292
# writing time step  3600 : t =  0.8999999999999286
# writing time step  3620 : t =  0.9049999999999281
# writing time step  3640 : t =  0.9099999999999275
# writing time step  3660 : t =  0.914999999999927
# writing time step  3680 : t =  0.9199999999999264
# writing time step  3700 : t =  0.9249999999999259
# writing time step  3720 : t =  0.9299999999999253
# writing time step  3740 : t =  0.9349999999999248
# writing time step  3760 : t =  0.9399999999999242
# writing time step  3780 : t =  0.9449999999999237
# writing time step  3800 : t =  0.9499999999999231
# writing time step  3820 : t =  0.9549999999999226
# writing time step  3840 : t =  0.959999999999922
# writing time step  3860 : t =  0.9649999999999215
# writing time step  3880 : t =  0.9699999999999209
# writing time step  3900 : t =  0.9749999999999204
# writing time step  3920 : t =  0.9799999999999198
# writing time step  3940 : t =  0.9849999999999193
# writing time step  3960 : t =  0.9899999999999187
# writing time step  3980 : t =  0.9949999999999182
# writing time step  4000 : t =  0.9999999999999176
# writing time step  4020 : t =  1.0049999999999193
# writing time step  4040 : t =  1.009999999999921
# writing time step  4060 : t =  1.0149999999999226
# writing time step  4080 : t =  1.0199999999999243
# writing time step  4100 : t =  1.024999999999926
# writing time step  4120 : t =  1.0299999999999276
# writing time step  4140 : t =  1.0349999999999293
# writing time step  4160 : t =  1.039999999999931
# writing time step  4180 : t =  1.0449999999999326
# writing time step  4200 : t =  1.0499999999999343
# writing time step  4220 : t =  1.054999999999936
# writing time step  4240 : t =  1.0599999999999377
# writing time step  4260 : t =  1.0649999999999393
# writing time step  4280 : t =  1.069999999999941
# writing time step  4300 : t =  1.0749999999999427
# writing time step  4320 : t =  1.0799999999999443
# writing time step  4340 : t =  1.084999999999946
# writing time step  4360 : t =  1.0899999999999477
# writing time step  4380 : t =  1.0949999999999493
# writing time step  4400 : t =  1.099999999999951
# writing time step  4420 : t =  1.1049999999999527
# writing time step  4440 : t =  1.1099999999999544
# writing time step  4460 : t =  1.114999999999956
# writing time step  4480 : t =  1.1199999999999577
# writing time step  4500 : t =  1.1249999999999594
# writing time step  4520 : t =  1.129999999999961
# writing time step  4540 : t =  1.1349999999999627
# writing time step  4560 : t =  1.1399999999999644
# writing time step  4580 : t =  1.144999999999966
# writing time step  4600 : t =  1.1499999999999677
# writing time step  4620 : t =  1.1549999999999694
# writing time step  4640 : t =  1.159999999999971
# writing time step  4660 : t =  1.1649999999999727
# writing time step  4680 : t =  1.1699999999999744
# writing time step  4700 : t =  1.174999999999976
# writing time step  4720 : t =  1.1799999999999777
# writing time step  4740 : t =  1.1849999999999794
# writing time step  4760 : t =  1.189999999999981
# writing time step  4780 : t =  1.1949999999999827
# writing time step  4800 : t =  1.1999999999999844
# writing time step  4820 : t =  1.204999999999986
# writing time step  4840 : t =  1.2099999999999878
# writing time step  4860 : t =  1.2149999999999894
# writing time step  4880 : t =  1.219999999999991
# writing time step  4900 : t =  1.2249999999999928
# writing time step  4920 : t =  1.2299999999999944
# writing time step  4940 : t =  1.234999999999996
# writing time step  4960 : t =  1.2399999999999978
# writing time step  4980 : t =  1.2449999999999994
# writing time step  5000 : t =  1.250000000000001
# writing time step  5020 : t =  1.2550000000000028
# writing time step  5040 : t =  1.2600000000000044
# writing time step  5060 : t =  1.2650000000000061
# writing time step  5080 : t =  1.2700000000000078
# writing time step  5100 : t =  1.2750000000000095
# writing time step  5120 : t =  1.2800000000000111
# writing time step  5140 : t =  1.2850000000000128
# writing time step  5160 : t =  1.2900000000000145
# writing time step  5180 : t =  1.2950000000000161
# writing time step  5200 : t =  1.3000000000000178
# writing time step  5220 : t =  1.3050000000000195
# writing time step  5240 : t =  1.3100000000000211
# writing time step  5260 : t =  1.3150000000000228
# writing time step  5280 : t =  1.3200000000000245
# writing time step  5300 : t =  1.3250000000000262
# writing time step  5320 : t =  1.3300000000000278
# writing time step  5340 : t =  1.3350000000000295
# writing time step  5360 : t =  1.3400000000000312
# writing time step  5380 : t =  1.3450000000000328
# writing time step  5400 : t =  1.3500000000000345
# writing time step  5420 : t =  1.3550000000000362
# writing time step  5440 : t =  1.3600000000000378
# writing time step  5460 : t =  1.3650000000000395
# writing time step  5480 : t =  1.3700000000000412
# writing time step  5500 : t =  1.3750000000000429
# writing time step  5520 : t =  1.3800000000000445
# writing time step  5540 : t =  1.3850000000000462
# writing time step  5560 : t =  1.3900000000000479
# writing time step  5580 : t =  1.3950000000000495
# writing time step  5600 : t =  1.4000000000000512
# writing time step  5620 : t =  1.4050000000000529
# writing time step  5640 : t =  1.4100000000000545
# writing time step  5660 : t =  1.4150000000000562
# writing time step  5680 : t =  1.4200000000000579
# writing time step  5700 : t =  1.4250000000000596
# writing time step  5720 : t =  1.4300000000000612
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-105964cb1022> in <module>
# ----> 1 strong.run(write_interval=0.005)
#       2 strong.post_process(error_quadrature_degree=4*p)
#
# ~/Research/GHOST/src/Solver.py in run(self, results_path, write_interval, clear_write_dir)
#     336             self.u_hat = self.time_integrator.run(self.u_hat, self.T,
#     337                                                   results_path,
# --> 338                                                   write_interval)
#     339
#     340             self.I_f = self.calculate_conserved_integral()
#
# ~/Research/GHOST/src/Discretization.py in run(self, u_0, T, results_path, write_interval)
#     908
#     909         for n in range(0,N_t):
# --> 910             u = np.copy(self.time_step(u,t,dt))
#     911             t = t + dt
#     912             if ((n+1) % N_write == 0) or (n+1 == N_t):
#
# ~/Research/GHOST/src/Discretization.py in time_step(self, u, t, dt)
#     940                             for k in range(0, len(u))]
#     941
# --> 942             r_u_tilde_nphalf = self.R(u_tilde_nphalf, t + 0.5*dt)
#     943
#     944             u_bar_np1 = [np.array([u[k][e,:] + dt * r_u_tilde_nphalf[k][e,:]
#
# ~/Research/GHOST/src/Discretization.py in <lambda>(u_hat, t)
#     582
#     583         return lambda u_hat, t: global_residual(self, f, f_star,
# --> 584                                                 bc, N_eq, u_hat, t)
#     585
#     586
#
# ~/Research/GHOST/src/Discretization.py in global_residual(self, f, f_star, bc, N_eq, u_hat, t, print_output)
#     527                         f_trans_gamma[k].append(self.Jf_gamma[k][gamma] * f_star(
#     528                             (self.V_gamma[i][gamma] @ u_hat[k].T).T, u_plus,
# --> 529                             self.x_gamma[k][gamma], self.n_gamma[k][gamma])
#     530                             - (self.V_gamma[i][gamma] @ self.P[i]
#     531                                @ sum([f_trans_omega[k][m].T*self.n_hat[i][gamma][m]
#
# ~/Research/GHOST/src/Problem.py in <lambda>(u_m, u_p, x, n)
#     230         return lambda u_m, u_p, x, n: np.array(
#     231             [f_star(self, u_m[:,i], u_p[:,i], n[:,i])
# --> 232                       for i in range(0,u_m.shape[1])]).T
#     233
#
# ~/Research/GHOST/src/Problem.py in <listcomp>(.0)
#     230         return lambda u_m, u_p, x, n: np.array(
#     231             [f_star(self, u_m[:,i], u_p[:,i], n[:,i])
# --> 232                       for i in range(0,u_m.shape[1])]).T
#     233
#
# ~/Research/GHOST/src/Problem.py in f_star(self, u_m, u_p, n)
#     214                                                     u_p[1]*n[0] + u_p[2]*n[1],
#     215                                                     -u_p[1]*n[1] + u_p[2]*n[0],
# --> 216                                                     u_p[3]]))
#     217
#     218                     return np.array([fn_2d[0],
#
# ~/Research/GHOST/src/Problem.py in roe_flux(self, u_m, u_p)
#     145                         v_p[0]*(u_p[3]+ p_p)])
#     146
# --> 147         return 0.5*(f_m + f_p) - 0.5*X @ (np.abs(eigval)*alpha)
#     148
#     149
#
# KeyboardInterrupt:

# %%
weak.run(write_interval=0.1)
weak.post_process(error_quadrature_degree=4*p)

# %%
print("{:.3e}".format(strong.calculate_difference(weak)), "&",
        "{:.3e}".format(strong.I_f - strong.I_0), "&",        
        "{:.3e}".format(weak.I_f- weak.I_0), "&",        
        "{:.3e}".format(strong.calculate_error()), "&",
        "{:.3e}".format(weak.calculate_error()))

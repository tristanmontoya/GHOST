# %%
mach_number=0.4
p=3
M=11
L=10.0
p_geo=1
c="c_dg"
discretization_type=1

# %%
import sys  
import pickle
sys.path.insert(0, '../src')
from Driver import euler_driver

solver = euler_driver(mach_number=mach_number, 
                        p=p, M=M, L=L,
                        p_geo=p_geo, c=c, 
                        discretization_type=discretization_type,
                        form="weak", run=False)

n_t = 20000 + (p-2)*8000

solver.load_solution(time_step=n_t)
solver.post_process(error_quadrature_degree=4*p)
# Out:
# WARNING:root:msh4 requires 3D points, but 2D points given. Appending 0 third component.
# WARNING:root:Binary Gmsh needs c_size_t (got int64). Converting.
# running solver euler_m04p3c0t1_weak

# %%
solver.plot(equation_index=0,u_range=[0.8,1.0],plot_curves=True,plot_exact=True)

# %%
solver.u_hmin
# Out:
# [0.8298630817607988,
#  -0.07388534229787336,
#  -0.059932875330696994,
#  1.4276988706411948]

# %%
solver.calculate_error()
# Out:
# array([0.0169675 , 0.06784492, 0.05504614, 0.05005666])

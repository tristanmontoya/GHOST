# %%
p=3
M=8
L=1
p_geo=1
c="c_+"
discretization_type=1
upwind_parameter=1.0
form="weak"

# %%
import sys  
import numpy as np
sys.path.insert(0, '../src')
from Driver import advection_driver

solver = advection_driver(a=np.sqrt(2), theta=np.pi/4, p=p, M=M, L=L,
                        p_geo=p_geo, c=c, 
                        discretization_type=discretization_type,
                        upwind_parameter=upwind_parameter,
                        form=form,run=False)
# Out:
# WARNING:root:msh4 requires 3D points, but 2D points given. Appending 0 third component.
# WARNING:root:Binary Gmsh needs c_size_t (got int64). Converting.
# advection_p3b1cpt1_weak

# %%
solver.load_solution(time_step=31678)
solver.post_process()
solver.plot()

# %%
K = solver.discretization.K

# %%
K
# Out:
# [array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  2.76740320e-32,  1.21399290e-31,
#           1.10973764e-17,  2.33376315e-32,  3.18357419e-32,
#           6.58439573e-18, -7.03090577e-32, -6.88426444e-18,
#           2.71384584e-18],
#         [ 0.00000000e+00,  1.21399290e-31,  7.64558801e-31,
#          -4.26563457e-16,  1.31839686e-31,  3.88767403e-31,
#          -7.54606457e-16, -3.35925545e-31, -3.90815590e-16,
#          -1.18141948e-16],
#         [ 0.00000000e+00,  1.10973764e-17, -4.26563457e-16,
#           1.64902500e+00, -2.85373317e-17, -4.38579828e-16,
#           2.37604554e+00,  7.34044479e-17,  5.84622094e-01,
#           6.25058747e-02],
#         [ 0.00000000e+00,  2.33376315e-32,  1.31839686e-31,
#          -2.85373317e-17,  2.52495154e-32,  6.45303289e-32,
#          -5.48192524e-17, -6.00974163e-32, -3.52170650e-17,
#          -1.39208538e-17],
#         [ 0.00000000e+00,  3.18357419e-32,  3.88767403e-31,
#          -4.38579828e-16,  6.45303289e-32,  3.71386086e-31,
#          -6.62910581e-16, -7.25765474e-32, -2.05989915e-16,
#          -3.48450313e-17],
#         [ 0.00000000e+00,  6.58439573e-18, -7.54606457e-16,
#           2.37604554e+00, -5.48192524e-17, -6.62910581e-16,
#           4.13437500e+00,  1.81234478e-16,  1.92148386e+00,
#           3.69789742e-01],
#         [ 0.00000000e+00, -7.03090577e-32, -3.35925545e-31,
#           7.34044479e-17, -6.00974163e-32, -7.25765474e-32,
#           1.81234478e-16,  2.13752897e-31,  1.69829646e-16,
#           8.31108772e-17],
#         [ 0.00000000e+00, -6.88426444e-18, -3.90815590e-16,
#           5.84622094e-01, -3.52170650e-17, -2.05989915e-16,
#           1.92148386e+00,  1.69829646e-16,  2.08372500e+00,
#           8.59313707e-01],
#         [ 0.00000000e+00,  2.71384584e-18, -1.18141948e-16,
#           6.25058747e-02, -1.39208538e-17, -3.48450313e-17,
#           3.69789742e-01,  8.31108772e-17,  8.59313707e-01,
#           8.26875000e-01]])]
